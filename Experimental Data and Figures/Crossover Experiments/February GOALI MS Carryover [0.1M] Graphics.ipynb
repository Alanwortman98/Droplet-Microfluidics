# %%
import pandas as pd
import matplotlib.pyplot as plt

#Full Dataset for formation at 0.6 µL/min (0.1M solutions). Sheath = 50:50 MeOH: H2O 0.5% Formic Acid
df_4_Cl_quinoline = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/4-CL-QUINOLINE.CSV')
df_7_azaindole = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/QUINOXALINE.CSV')

plt.figure(figsize = (10,6))

#Create an axis object ax = plt.subplot()... then use ax.xyz

ax = plt.subplot()

x1 = df_4_Cl_quinoline['time']
y1 = df_4_Cl_quinoline['intensity']

x2 = df_7_azaindole['time']
y2 = df_7_azaindole['intensity']

x3 = df_ethyl_isonicotinate['time']
y3 = df_ethyl_isonicotinate['intensity']

x4 = df_quinoxaline['time']
y4 = df_quinoxaline['intensity']

ax.plot(x1,y1, color = '#58508d', label = '4-Cl-Quinoline')
ax.plot(x2,y2, color = '#ff6361', label = '7-Azaindole', alpha = 0.25)
ax.plot(x3,y3, color = '#bc5090', label = 'Ethyl Isonicotinate', alpha = 0.25)
ax.plot(x4,y4, color = '#ffa600', label = 'Quinoxaline', alpha = 0.25)

ax.set_xlim(1.75, 7.25)
ax.set_xlabel('Time (min)')
ax.set_ylabel ('Abundance')
ax.spines[['right', 'top']].set_visible(False)
plt.legend(frameon = False)
plt.title('Analysis of Both Droplet Sets 0.6 µL/min')
plt.savefig('Combination & Carryover.jpeg', dpi = 300)

# %%
#Looking at combinations for 0.6 µL/min formation. Sheath = 50:50 MeOH: H2O 0.5% Formic Acid

plt.figure(figsize = (10,6))

ax1 = plt.subplot (1,2,1)
ax1.plot(x1,y1, color = '#58508d', label = '4-Cl-Quinoline')
ax1.plot(x2,y2, color = '#ff6361', label = '7-Azaindole')
ax1.spines[['right', 'top']].set_visible(False)
ax1.set_xlabel('Time (min)')
ax1.set_ylabel ('Abundance')
ax1.legend(loc = 'best', frameon = False)
ax1.set_xlim(1.75,4)
ax1.set_title('Droplet Set 1')

ax2 = plt.subplot (1,2,2)
ax2.plot(x3,y3, color = '#bc5090', label = 'Ethyl Isonicotinate')
ax2.plot(x4,y4, color = '#ffa600', label = 'Quinoxaline')
ax2.spines[['right', 'top']].set_visible(False)
ax2.set_xlabel('Time (min)')
ax2.set_ylabel ('Abundance')
ax2.set_xlim(1.75, 4)
ax2.set_title('Droplet Set 2')

ax2.legend(loc = 'best', frameon = False)
plt.savefig('Comparing Individual Sets.jpeg', dpi = 300)

# %%
#Looking at carryover for the 0.6 µL/min formation. Sheath = 50:50 MeOH: H2O 0.5% Formic Acid

plt.figure(figsize = (10,6))

ax3 = plt.subplot()
ax3.plot(x1, y1, label = '4-Cl-Quinoline', color = '#58508d')
ax3.plot(x3, y3, label = 'Ethyl Isonicotinate', color = '#bc5090')
ax3.legend(loc = 'upper right', frameon = False)
ax3.set_xlim(1.75, 4)
ax3.set_xlabel('Time (min)')
ax3.set_ylabel('Abundance')
ax3.spines[['right', 'top']].set_visible(False)
ax3.set_title('Comparing Overlap of Set 1 & 2')
plt.savefig('Comparing Different Set Overlap.jpeg', dpi = 300)

# %%
#Full Dataset for forming the droplets at 0.8 µL/min. Sheath = 50:50 MeOH: H2O 0.5% Formic Acid

df_4_Cl_quinoline2 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.8ul per min-1204pm/4-CL-QUINOLINE.CSV')
df_7_azaindole2 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.8ul per min-1204pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate2 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.8ul per min-1204pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline2 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.8ul per min-1204pm/QUINOXALINE.CSV')

plt.figure(figsize = (10,6))
ax4 = plt.subplot()

x5 = df_4_Cl_quinoline2['time']
y5 = df_4_Cl_quinoline2['abundance']

x6 = df_7_azaindole2['time']
y6 = df_7_azaindole2['abundance']

x7 = df_ethyl_isonicotinate2['time']
y7 = df_ethyl_isonicotinate2['abundance']

x8 = df_quinoxaline2['time']
y8 = df_quinoxaline2['abundance']

ax4.plot(x5,y5, color = '#58508d', label = '4-Cl-Quinoline')
ax4.plot(x6,y6, color = '#ff6361', label = '7-Azaindole', alpha = 0.25)
ax4.plot(x7,y7, color = '#bc5090', label = 'Ethyl Isonicotinate', alpha = 0.25)
ax4.plot(x8,y8, color = '#ffa600', label = 'Quinoxaline', alpha = 0.25)

ax4.set_xlim(0, 6)
ax4.set_ylim(0, 650000)
ax4.set_xlabel('Time (min)')
ax4.set_ylabel ('Abundance')
ax4.spines[['right', 'top']].set_visible(False)
plt.legend(frameon = False)
plt.title('Analysis of Both Droplet Sets 0.8 µL/min')
plt.savefig('Combination & Carryover 0.8s.jpeg', dpi = 300)

# %%
#Plotting the full data set of spacing the droplets by 10s of oil. Sheath = 50:50 MeOH: H2O 0.5% Formic Acid

df_4_Cl_quinoline_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/4-CL-QUINOLINE.CSV')
df_7_azaindole_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/QUINOXALINE.CSV')

x1_10s = df_4_Cl_quinoline_10s['time']
y1_10s = df_4_Cl_quinoline_10s['abundance']
x2_10s = df_7_azaindole_10s['time']
y2_10s = df_7_azaindole_10s['abundance']
x3_10s = df_ethyl_isonicotinate_10s['time']
y3_10s = df_ethyl_isonicotinate_10s['abundance']
x4_10s = df_quinoxaline_10s['time']
y4_10s = df_quinoxaline_10s['abundance']



plt.figure(figsize = (10,6))
ax_10s = plt.subplot()

ax_10s.plot(x1_10s,y1_10s, color = '#58508d', label = '4-Cl-Quinoline')
ax_10s.plot(x2_10s,y2_10s, color = '#ff6361', label = '7-Azaindole', alpha = 0.25)
ax_10s.plot(x3_10s,y3_10s, color = '#bc5090', label = 'Ethyl Isonicotinate', alpha = 0.25)
ax_10s.plot(x4_10s,y4_10s, color = '#ffa600', label = 'Quinoxaline', alpha = 0.25)
plt.legend(loc = 'upper right', frameon = False)
ax_10s.set_xlabel('Time (Min)')
ax_10s.set_ylabel('Abundance')
ax_10s.set_title('10s Oil Spacing')
# ax_10s.ticklabel_format(style = 'scientific')
ax_10s.set_xlim(1.5, 10)

ax_10s.spines[['top', 'right']].set_visible(False)

plt.savefig('10s Oil Carryover.jpeg', dpi = 300)

# %%
#Comparing Crossover for two analytes in the 10s oil spacing. Sheath = 50:50 MeOH: H2O 0.5% Formic Acid

df_4_Cl_quinoline_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/4-CL-QUINOLINE.CSV')
df_7_azaindole_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_10s = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/10s-1235pm/QUINOXALINE.CSV')

x1_10s = df_4_Cl_quinoline_10s['time']
y1_10s = df_4_Cl_quinoline_10s['abundance']
x2_10s = df_7_azaindole_10s['time']
y2_10s = df_7_azaindole_10s['abundance']
x3_10s = df_ethyl_isonicotinate_10s['time']
y3_10s = df_ethyl_isonicotinate_10s['abundance']
x4_10s = df_quinoxaline_10s['time']
y4_10s = df_quinoxaline_10s['abundance']



plt.figure(figsize = (10,6))
ax_10s = plt.subplot()

ax_10s.plot(x1_10s,y1_10s, color = '#58508d', label = '4-Cl-Quinoline')

ax_10s.plot(x3_10s,y3_10s, color = '#bc5090', label = 'Ethyl Isonicotinate')

plt.legend(loc = 'upper right', frameon = False)
ax_10s.set_xlabel('Time (Min)')
ax_10s.set_ylabel('Abundance')
ax_10s.set_title('Comparing Overlap 10s Oil')
# ax_10s.ticklabel_format(style = 'scientific')
ax_10s.set_xlim(1.5, 5)
ax_10s.set_ylim(0, 1000000)

ax_10s.spines[['top', 'right']].set_visible(False)

plt.savefig('10s Oil Carryover Comparison.jpeg', dpi = 300)

# %%
#Looking at full data set for using 50:50 MeOH:H2O 10 mM ammonium formate as sheath fluid. 

df_4_Cl_quinoline_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/4-CL-QUINOLINE.CSV')
df_7_azaindole_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/QUINOXALINE.CSV')

x1_formate = df_4_Cl_quinoline_formate['time']
y1_formate = df_4_Cl_quinoline_formate['abundance']
x2_formate = df_7_azaindole_formate['time']
y2_formate = df_7_azaindole_formate['abundance']
x3_formate = df_ethyl_isonicotinate_formate['time']
y3_formate = df_ethyl_isonicotinate_formate['abundance']
x4_formate = df_quinoxaline_formate['time']
y4_formate = df_quinoxaline_formate['abundance']

plt.figure(figsize = (10,6))
ax_formate = plt.subplot()
ax_formate.plot(x1_formate, y1_formate, color = '#58508d', label = '4-Cl-Quinoline')
ax_formate.plot(x2_formate, y2_formate, color = '#ff6361', label = '7-Azaindole', alpha = 0.25)
ax_formate.plot(x3_formate, y3_formate, color = '#bc5090', label = 'Ethyl Isonicotinate', alpha = 0.25)
ax_formate.plot(x4_formate, y4_formate, color = '#ffa600', label = 'Quinoxaline', alpha = 0.25)
ax_formate.set_xlabel('Time (Min)')
ax_formate.set_xlim(1.5, 7.5)
ax_formate.set_ylabel('Abundance')
ax_formate.set_ylim(0, 175000)
ax_formate.set_title('50:50 MeOH : H$_{2}$O, 10mM Ammonium Formate')

plt.legend(loc = 'upper right', frameon = False)
ax_formate.spines[['top', 'right']].set_visible(False)

plt.savefig('Ammonium Formate Sheath Carryover.jpeg', dpi = 300)

# %%
#Honestly would be easier to merge these data frames into a single one by reading all the csv's....

df_4_Cl_quinoline_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/4-CL-QUINOLINE.CSV')
df_7_azaindole_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_formate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0127/NH4HCOO-0305pm/QUINOXALINE.CSV')

# %%
df_4_Cl_quinoline_MeCN_500 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0130/0417pm/4-CL.CSV')
df_7_azaindole_MeCN_500 = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0130/0417pm/7-AZAINDOLE.CSV')


x1_MeCN = df_4_Cl_quinoline_MeCN_500['time']
y1_MeCN = df_4_Cl_quinoline_MeCN_500['abundance']
x2_MeCN = df_7_azaindole_MeCN_500['time']
y2_MeCN = df_7_azaindole_MeCN_500['abundance']

plt.figure(figsize = (10,6))
ax_MeCN = plt.subplot()

ax_MeCN.plot(x1,y1, color = '#58508d', label = '4-Cl-Quinoline')
ax_MeCN.plot(x2,y2, color = '#ff6361', label = '7-Azaindole')

ax_MeCN.set_xlabel('Time (Min)')
ax_MeCN.set_xlim(1.5,8)

ax_MeCN.set_ylabel('Abundance')
# Out:
# Text(0, 0.5, 'Abundance')

# %%
df_4_Cl_quinoline_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/4-CL-QUINOLINE.CSV')
df_7_azaindole_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/QUINOXALINE.CSV')

x1_SIM = df_4_Cl_quinoline_SIM_dwell['time']
y1_SIM = df_4_Cl_quinoline_SIM_dwell['abundance']
x2_SIM = df_7_azaindole_SIM_dwell['time']
y2_SIM = df_7_azaindole_SIM_dwell['abundance']
x3_SIM = df_ethyl_isonicotinate_SIM_dwell['time']
y3_SIM = df_ethyl_isonicotinate_SIM_dwell['abundance']
x4_SIM = df_quinoxaline_SIM_dwell['time']
y4_SIM = df_quinoxaline_SIM_dwell['abundance']

plt.figure(figsize = (10,6))
ax_SIM_dwell = plt.subplot(1,2,1)

ax_SIM_dwell.plot(x1_SIM, y1_SIM, color = '#ff6361', label = '4-Cl-Quinoline')
ax_SIM_dwell.plot(x2_SIM, y2_SIM, color = '#58508d', label = '7-Azaindole')
ax_SIM_dwell.set_xlim(4,8)
ax_SIM_dwell.set_xlabel('Time (Min)')
ax_SIM_dwell.set_ylabel('Abundance')
plt.legend(loc = 'upper right', frameon = False)
plt.title('Combination Within Set')
ax_SIM_dwell.spines[['top', 'right']].set_visible(False)

'#bc5090'

ax_SIM_dwell2 = plt.subplot(1,2,2)
ax_SIM_dwell2.plot(x3_SIM, y3_SIM, color = '#ffa600', label = 'Ethyl Isonicotinate')
ax_SIM_dwell2.plot(x4_SIM, y4_SIM, color = '#bc5090', label = 'Quinoxaline')
ax_SIM_dwell2.set_xlim(4,8)
ax_SIM_dwell2.set_xlabel('Time (Min)')
ax_SIM_dwell2.set_ylabel('Abundance')
plt.legend(loc = 'upper right', frameon = False)
plt.title('Combination Within Set')
ax_SIM_dwell2.spines[['top', 'right']].set_visible(False)

plt.savefig('SIM dwell combinations.jpeg', dpi = 300)

# %%
#Plotting the same graph, but using 2 Y axes so one plot doesn't dwarf another

df_4_Cl_quinoline_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/4-CL-QUINOLINE.CSV')
df_7_azaindole_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/ETHYL ISONICOTINATE.CSV')
df_quinoxaline_SIM_dwell = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0202/QUINOXALINE.CSV')

#Defining our X and Y values for each substrate

x1_SIM = df_4_Cl_quinoline_SIM_dwell['time']
y1_SIM = df_4_Cl_quinoline_SIM_dwell['abundance']
x2_SIM = df_7_azaindole_SIM_dwell['time']
y2_SIM = df_7_azaindole_SIM_dwell['abundance']
x3_SIM = df_ethyl_isonicotinate_SIM_dwell['time']
y3_SIM = df_ethyl_isonicotinate_SIM_dwell['abundance']
x4_SIM = df_quinoxaline_SIM_dwell['time']
y4_SIM = df_quinoxaline_SIM_dwell['abundance']


#Making the first half of the figure

plt.figure(figsize = (10, 6))
ax_SIM_dwell = plt.subplot()

ax_SIM_dwell.plot(x1_SIM, y1_SIM, color = '#ff6361', label = '4-Cl-Quinoline')
ax_SIM_dwell.set_xlim(4,8)
ax_SIM_dwell.set_xlabel('Time (Min)')
plt.legend(loc = (0.8, 0.95), frameon = False)
ax_SIM_dwell.set_ylim(0, 1.5e6)
ax_SIM_dwell.set_ylabel('Abundance')
ax_SIM_dwell.spines[['top']].set_visible(False)
plt.title('Comparison Among Droplet Sets')


ax_SIM_dwell2 = ax_SIM_dwell.twinx()
ax_SIM_dwell2.plot(x4_SIM, y4_SIM, color = '#bc5090', label = 'Quinoxaline')
plt.legend(loc = (0.8, 0.9), frameon = False)
ax_SIM_dwell2.set_ylim(0, 350000)
ax_SIM_dwell2.spines[['top']].set_visible(False)

plt.savefig('SIM dwell carryover 1.jpeg', dpi = 300)





#Making The second half of the figure




plt.figure(figsize = (10, 6))
ax_SIM_dwell3 = plt.subplot()
ax_SIM_dwell3.plot(x3_SIM, y3_SIM, color = '#ffa600', label = 'Ethyl Isonicotinate')
plt.legend(loc = (0.75, 0.95), frameon = False)
ax_SIM_dwell3.set_xlabel('Time (Min)')
ax_SIM_dwell3.set_ylim(0, 2.7e6)
ax_SIM_dwell3.set_ylabel('Abundance')
ax_SIM_dwell3.spines[['top']].set_visible(False)
plt.title('Comparison Among Droplet Sets')


ax_SIM_dwell4 = ax_SIM_dwell3.twinx()
ax_SIM_dwell4.plot(x2_SIM, y2_SIM, color = '#58508d', label = '7-Azaindole')
ax_SIM_dwell4.set_ylim(0, 1.2e6)
ax_SIM_dwell4.set_xlim(4,8)
plt.legend(loc = (0.75, 0.9), frameon = False)
ax_SIM_dwell4.spines[['top']].set_visible(False)

plt.savefig('SIM dwell carryover 2.jpeg', dpi = 300)

# %%
#Playing around with seaborn to plot some of the data in the first graph

import seaborn as sns

df_4_Cl_quinoline = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/4-CL-QUINOLINE.CSV')
df_7_azaindole = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/7-AZAINDOLE.CSV')
df_ethyl_isonicotinate = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/ETHYL ISONICOTINATE.CSV')
df_quinoxaline = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/0126 and 0127 data/0126/0.6ul per min-0559pm/QUINOXALINE.CSV')

plt.figure(figsize = (10,6))
sns.lineplot(data = df_4_Cl_quinoline, x = df_4_Cl_quinoline.time, y = df_4_Cl_quinoline.intensity, label = '4-Cl-quinoline')
sns.lineplot(data = df_7_azaindole, x = df_7_azaindole.time, y = df_7_azaindole.intensity, label = '7-azaindole')
plt.legend()

sns.despine()

#Try loading all the MS data into a single data frame using pandas, then plotting by hue to see if they all show up on the same graph (hue = intensity)
