# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/alanwortman/Desktop/Grad School/Stephenson/Droplet Microfluidics/Experimental Data/Methyl_Red_3x1_test_crossover_more_sensitive_009.csv')
# sns.lineplot(data = df, x = 'time', y = 'absorbance (510 nm)')

# droplets_beginning_to_middle = df[df.time >= 360]
droplets_beginning_to_middle = df[df['time'].between(300, 400)]
fig, ax = plt.subplots(figsize= (10, 5))
sns.lineplot(data = droplets_beginning_to_middle, x = 'time', y = 'absorbance (510 nm)')
# Out:
# <AxesSubplot: xlabel='time', ylabel='absorbance (510 nm)'>

# %% [markdown]
# ####
